# %%
# !pip3 install dlib
# %pip install cmake
# !pip3 install face_recognition

import face_recognition
import cv2
from multiprocessing import Process, Manager, cpu_count, set_start_method
import time
import numpy as np
import os
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dlib
#   Using cached dlib-19.24.2-cp39-cp39-macosx_13_0_universal2.whl
# Installing collected packages: dlib
# Successfully installed dlib-19.24.2
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cmake
#   Using cached cmake-3.26.4-py2.py3-none-macosx_10_10_universal2.macosx_10_10_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (45.6 MB)
# Installing collected packages: cmake
# Successfully installed cmake-3.26.4
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /Users/abhay/Library/Python/3.9/lib/python/site-packages (from face_recognition) (1.25.0)
# Requirement already satisfied: Pillow in /Users/abhay/Library/Python/3.9/lib/python/site-packages (from face_recognition) (9.5.0)
# Requirement already satisfied: dlib>=19.7 in /Users/abhay/Library/Python/3.9/lib/python/site-packages (from face_recognition) (19.24.2)
# Collecting Click>=6.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Installing collected packages: face-recognition-models, Click, face-recognition
# Successfully installed Click-8.1.3 face-recognition-1.3.0 face-recognition-models-0.3.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# #### Preprocessing Data and Multithread Setup

# %%
# Define the dataset directory
dataset_dir = './data/people'

known_faces = []
known_labels = []
for label_name in os.listdir(dataset_dir):
    label_dir = os.path.join(dataset_dir, label_name)
    if os.path.isdir(label_dir):
        for img_name in os.listdir(label_dir):
            img_path = os.path.join(label_dir, img_name)
            print("Processing image:", img_path)  # Debugging statement
            try:
                image = face_recognition.load_image_file(img_path)
                face_encodings = face_recognition.face_encodings(image)
                if len(face_encodings) > 0:
                    face_encoding = face_encodings[0]
                    known_faces.append(face_encoding)
                    known_labels.append(label_name)
                else:
                    print("Error: No face found in", img_path)
                    os.remove(img_path)
            except Exception as e:
                print("Error processing image:", img_path)
                print("Error message:", str(e))
                os.remove(img_path)
# Out:
# Processing image: ./data/people/gates/gates99.jpg
# Processing image: ./data/people/gates/gates117.jpg
# Processing image: ./data/people/gates/gates103.jpg
# Processing image: ./data/people/gates/gates72.jpg
# Processing image: ./data/people/gates/gates66.jpg
# Processing image: ./data/people/gates/gates67.jpg
# Processing image: ./data/people/gates/gates73.jpg
# Processing image: ./data/people/gates/gates116.jpg
# Processing image: ./data/people/gates/gates98.jpg
# Processing image: ./data/people/gates/gates100.jpg
# Processing image: ./data/people/gates/gates114.jpg
# Processing image: ./data/people/gates/gates59.jpg
# Processing image: ./data/people/gates/gates65.jpg
# Processing image: ./data/people/gates/gates71.jpg
# Processing image: ./data/people/gates/gates70.jpg
# Processing image: ./data/people/gates/gates64.jpg
# Processing image: ./data/people/gates/gates58.jpg
# Processing image: ./data/people/gates/gates115.jpg
# Processing image: ./data/people/gates/gates101.jpg
# Processing image: ./data/people/gates/gates105.jpg
# Processing image: ./data/people/gates/gates111.jpg
# Processing image: ./data/people/gates/gates139.jpg
# Processing image: ./data/people/gates/gates60.jpg
# Processing image: ./data/people/gates/gates74.jpg
# Processing image: ./data/people/gates/gates48.jpg
# Processing image: ./data/people/gates/gates49.jpg
# Processing image: ./data/people/gates/gates75.jpg
# Processing image: ./data/people/gates/gates61.jpg
# Processing image: ./data/people/gates/gates138.jpg
# Processing image: ./data/people/gates/gates110.jpg
# Processing image: ./data/people/gates/gates112.jpg
# Processing image: ./data/people/gates/gates106.jpg
# Processing image: ./data/people/gates/gates88.jpg
# Processing image: ./data/people/gates/gates77.jpg
# Processing image: ./data/people/gates/gates63.jpg
# Processing image: ./data/people/gates/gates62.jpg
# Processing image: ./data/people/gates/gates76.jpg
# Processing image: ./data/people/gates/gates89.jpg
# Processing image: ./data/people/gates/gates107.jpg
# Processing image: ./data/people/gates/gates113.jpg
# Processing image: ./data/people/gates/gates148.jpg
# Processing image: ./data/people/gates/gates39.jpg
# Processing image: ./data/people/gates/gates11.jpg
# Processing image: ./data/people/gates/gates10.jpg
# Processing image: ./data/people/gates/gates38.jpg
# Processing image: ./data/people/gates/gates149.jpg
# Processing image: ./data/people/gates/gates12.jpg
# Processing image: ./data/people/gates/gates13.jpg
# Processing image: ./data/people/gates/gates17.jpg
# Error: No face found in ./data/people/gates/gates17.jpg
# Processing image: ./data/people/gates/gates16.jpg
# Processing image: ./data/people/gates/gates14.jpg
# Processing image: ./data/people/gates/gates28.jpg
# Processing image: ./data/people/gates/gates9.jpg
# Processing image: ./data/people/gates/gates8.jpg
# Processing image: ./data/people/gates/gates29.jpg
# Processing image: ./data/people/gates/gates15.jpg
# Processing image: ./data/people/gates/gates141.jpg
# Error: No face found in ./data/people/gates/gates141.jpg
# Processing image: ./data/people/gates/gates18.jpg
# Processing image: ./data/people/gates/gates30.jpg
# Processing image: ./data/people/gates/gates5.jpg
# Processing image: ./data/people/gates/gates24.jpg
# Processing image: ./data/people/gates/gates25.jpg
# Processing image: ./data/people/gates/gates4.jpg
# Processing image: ./data/people/gates/gates31.jpg
# Processing image: ./data/people/gates/gates19.jpg
# Processing image: ./data/people/gates/gates142.jpg
# Processing image: ./data/people/gates/gates27.jpg
# Processing image: ./data/people/gates/gates33.jpg
# Error: No face found in ./data/people/gates/gates33.jpg
# Processing image: ./data/people/gates/gates6.jpg
# Processing image: ./data/people/gates/gates7.jpg
# Processing image: ./data/people/gates/gates32.jpg
# Processing image: ./data/people/gates/gates26.jpg
# Processing image: ./data/people/gates/gates143.jpg
# Processing image: ./data/people/gates/gates22.jpg
# Processing image: ./data/people/gates/gates36.jpg
# Processing image: ./data/people/gates/gates3.jpg
# Processing image: ./data/people/gates/gates2.jpg
# Processing image: ./data/people/gates/gates37.jpg
# Processing image: ./data/people/gates/gates23.jpg
# Processing image: ./data/people/gates/gates146.jpg
# Processing image: ./data/people/gates/gates144.jpg
# Processing image: ./data/people/gates/gates35.jpg
# Processing image: ./data/people/gates/gates0.jpg
# Processing image: ./data/people/gates/gates21.jpg
# Processing image: ./data/people/gates/gates20.jpg
# Processing image: ./data/people/gates/gates1.jpg
# Processing image: ./data/people/gates/gates34.jpg
# Processing image: ./data/people/gates/gates145.jpg
# Processing image: ./data/people/gates/gates136.jpg
# Processing image: ./data/people/gates/gates90.jpg
# Processing image: ./data/people/gates/gates122.jpg
# Processing image: ./data/people/gates/gates84.jpg
# Processing image: ./data/people/gates/gates53.jpg
# Processing image: ./data/people/gates/gates47.jpg
# Processing image: ./data/people/gates/gates46.jpg
# Processing image: ./data/people/gates/gates52.jpg
# Processing image: ./data/people/gates/gates85.jpg
# Processing image: ./data/people/gates/gates123.jpg
# Processing image: ./data/people/gates/gates91.jpg
# Processing image: ./data/people/gates/gates109.jpg
# Processing image: ./data/people/gates/gates121.jpg
# Processing image: ./data/people/gates/gates87.jpg
# Processing image: ./data/people/gates/gates93.jpg
# Processing image: ./data/people/gates/gates78.jpg
# Processing image: ./data/people/gates/gates44.jpg
# Processing image: ./data/people/gates/gates50.jpg
# Processing image: ./data/people/gates/gates51.jpg
# Processing image: ./data/people/gates/gates45.jpg
# Processing image: ./data/people/gates/gates79.jpg
# Processing image: ./data/people/gates/gates92.jpg
# Processing image: ./data/people/gates/gates86.jpg
# Processing image: ./data/people/gates/gates120.jpg
# Processing image: ./data/people/gates/gates108.jpg
# Processing image: ./data/people/gates/gates124.jpg
# Processing image: ./data/people/gates/gates82.jpg
# Processing image: ./data/people/gates/gates130.jpg
# Processing image: ./data/people/gates/gates96.jpg
# Processing image: ./data/people/gates/gates41.jpg
# Processing image: ./data/people/gates/gates55.jpg
# Processing image: ./data/people/gates/gates69.jpg
# Processing image: ./data/people/gates/gates68.jpg
# Error: No face found in ./data/people/gates/gates68.jpg
# Processing image: ./data/people/gates/gates54.jpg
# Processing image: ./data/people/gates/gates40.jpg
# Processing image: ./data/people/gates/gates119.jpg
# Processing image: ./data/people/gates/gates97.jpg
# Processing image: ./data/people/gates/gates131.jpg
# Processing image: ./data/people/gates/gates83.jpg
# Processing image: ./data/people/gates/gates95.jpg
# Processing image: ./data/people/gates/gates127.jpg
# Processing image: ./data/people/gates/gates81.jpg
# Processing image: ./data/people/gates/gates56.jpg
# Processing image: ./data/people/gates/gates42.jpg
# Processing image: ./data/people/gates/gates43.jpg
# Processing image: ./data/people/gates/gates57.jpg
# Processing image: ./data/people/gates/gates80.jpg
# Processing image: ./data/people/gates/gates126.jpg
# Processing image: ./data/people/gates/gates94.jpg
# Processing image: ./data/people/musk/musk145.jpg
# Processing image: ./data/people/musk/musk96.jpg
# Processing image: ./data/people/musk/musk55.jpg
# Processing image: ./data/people/musk/musk41.jpg
# Processing image: ./data/people/musk/musk40.jpg
# Processing image: ./data/people/musk/musk54.jpg
# Processing image: ./data/people/musk/musk83.jpg
# Processing image: ./data/people/musk/musk144.jpg
# Processing image: ./data/people/musk/musk146.jpg
# Processing image: ./data/people/musk/musk81.jpg
# Processing image: ./data/people/musk/musk95.jpg
# Processing image: ./data/people/musk/musk42.jpg
# Processing image: ./data/people/musk/musk56.jpg
# Processing image: ./data/people/modi/modi103.jpg
# Processing image: ./data/people/modi/modi116.jpg
# Processing image: ./data/people/modi/modi102.jpg
# Processing image: ./data/people/modi/modi68.jpg
# Processing image: ./data/people/modi/modi54.jpg
# Processing image: ./data/people/modi/modi40.jpg
# Processing image: ./data/people/modi/modi97.jpg
# Processing image: ./data/people/modi/modi83.jpg
# Processing image: ./data/people/modi/modi95.jpg
# Processing image: ./data/people/modi/modi81.jpg
# Processing image: ./data/people/modi/modi56.jpg
# Processing image: ./data/people/modi/modi42.jpg
# Processing image: ./data/people/modi/modi128.jpg
# Processing image: ./data/people/modi/modi114.jpg
# Processing image: ./data/people/modi/modi100.jpg
# Processing image: ./data/people/modi/modi115.jpg
# Processing image: ./data/people/modi/modi129.jpg
# Processing image: ./data/people/modi/modi43.jpg
# Processing image: ./data/people/modi/modi57.jpg
# Processing image: ./data/people/modi/modi80.jpg
# Processing image: ./data/people/modi/modi94.jpg
# Processing image: ./data/people/modi/modi90.jpg
# Processing image: ./data/people/modi/modi84.jpg
# Processing image: ./data/people/modi/modi53.jpg
# Processing image: ./data/people/modi/modi47.jpg
# Processing image: ./data/people/modi/modi111.jpg
# Processing image: ./data/people/modi/modi105.jpg
# Processing image: ./data/people/modi/modi139.jpg
# Processing image: ./data/people/modi/modi138.jpg
# Processing image: ./data/people/modi/modi104.jpg
# Processing image: ./data/people/modi/modi110.jpg
# Processing image: ./data/people/modi/modi46.jpg
# Processing image: ./data/people/modi/modi52.jpg
# Processing image: ./data/people/modi/modi85.jpg
# Processing image: ./data/people/modi/modi91.jpg
# Processing image: ./data/people/modi/modi87.jpg
# Processing image: ./data/people/modi/modi93.jpg
# Processing image: ./data/people/modi/modi78.jpg
# Processing image: ./data/people/modi/modi44.jpg
# Processing image: ./data/people/modi/modi106.jpg
# Processing image: ./data/people/modi/modi112.jpg
# Processing image: ./data/people/modi/modi113.jpg
# Processing image: ./data/people/modi/modi51.jpg
# Processing image: ./data/people/modi/modi45.jpg
# Processing image: ./data/people/modi/modi79.jpg
# Processing image: ./data/people/modi/modi92.jpg
# Processing image: ./data/people/modi/modi86.jpg
# Processing image: ./data/people/modi/modi36.jpg
# Processing image: ./data/people/modi/modi148.jpg
# Processing image: ./data/people/modi/modi149.jpg
# Processing image: ./data/people/modi/modi37.jpg
# Processing image: ./data/people/modi/modi23.jpg
# Processing image: ./data/people/modi/modi35.jpg
# Processing image: ./data/people/modi/modi20.jpg
# Processing image: ./data/people/modi/modi34.jpg
# Processing image: ./data/people/modi/modi18.jpg
# Processing image: ./data/people/modi/modi30.jpg
# Error: No face found in ./data/people/modi/modi30.jpg
# Processing image: ./data/people/modi/modi24.jpg
# Processing image: ./data/people/modi/modi8.jpg
# Processing image: ./data/people/modi/modi9.jpg
# Processing image: ./data/people/modi/modi25.jpg
# Error: No face found in ./data/people/modi/modi25.jpg
# Processing image: ./data/people/modi/modi31.jpg
# Processing image: ./data/people/modi/modi19.jpg
# Processing image: ./data/people/modi/modi27.jpg
# Processing image: ./data/people/modi/modi33.jpg
# Processing image: ./data/people/modi/modi32.jpg
# Processing image: ./data/people/modi/modi26.jpg
# Processing image: ./data/people/modi/modi17.jpg
# Processing image: ./data/people/modi/modi7.jpg
# Processing image: ./data/people/modi/modi141.jpg
# Processing image: ./data/people/modi/modi140.jpg
# Processing image: ./data/people/modi/modi6.jpg
# Processing image: ./data/people/modi/modi16.jpg
# Processing image: ./data/people/modi/modi14.jpg
# Processing image: ./data/people/modi/modi28.jpg
# Error: No face found in ./data/people/modi/modi28.jpg
# Processing image: ./data/people/modi/modi4.jpg
# Processing image: ./data/people/modi/modi142.jpg
# Processing image: ./data/people/modi/modi143.jpg
# Processing image: ./data/people/modi/modi5.jpg
# Processing image: ./data/people/modi/modi29.jpg
# Processing image: ./data/people/modi/modi15.jpg
# Error: No face found in ./data/people/modi/modi15.jpg
# Processing image: ./data/people/modi/modi39.jpg
# Error: No face found in ./data/people/modi/modi39.jpg
# Processing image: ./data/people/modi/modi11.jpg
# Processing image: ./data/people/modi/modi1.jpg
# Error: No face found in ./data/people/modi/modi1.jpg
# Processing image: ./data/people/modi/modi147.jpg
# Processing image: ./data/people/modi/modi146.jpg
# Processing image: ./data/people/modi/modi0.jpg
# Processing image: ./data/people/modi/modi10.jpg
# Processing image: ./data/people/modi/modi38.jpg
# Processing image: ./data/people/modi/modi12.jpg
# Processing image: ./data/people/modi/modi2.jpg
# Processing image: ./data/people/modi/modi144.jpg
# Processing image: ./data/people/modi/modi150.jpg
# Processing image: ./data/people/modi/modi151.jpg
# Processing image: ./data/people/modi/modi145.jpg
# Processing image: ./data/people/modi/modi3.jpg
# Processing image: ./data/people/modi/modi13.jpg
# Processing image: ./data/people/modi/modi60.jpg
# Processing image: ./data/people/modi/modi74.jpg
# Processing image: ./data/people/modi/modi48.jpg
# Processing image: ./data/people/modi/modi136.jpg
# Processing image: ./data/people/modi/modi137.jpg
# Processing image: ./data/people/modi/modi123.jpg
# Processing image: ./data/people/modi/modi49.jpg
# Processing image: ./data/people/modi/modi75.jpg
# Processing image: ./data/people/modi/modi61.jpg
# Processing image: ./data/people/modi/modi88.jpg
# Processing image: ./data/people/modi/modi77.jpg
# Processing image: ./data/people/modi/modi63.jpg
# Processing image: ./data/people/modi/modi109.jpg
# Processing image: ./data/people/modi/modi135.jpg
# Processing image: ./data/people/modi/modi120.jpg
# Processing image: ./data/people/modi/modi134.jpg
# Processing image: ./data/people/modi/modi62.jpg
# Processing image: ./data/people/modi/modi76.jpg
# Processing image: ./data/people/modi/modi89.jpg
# Processing image: ./data/people/modi/modi99.jpg
# Processing image: ./data/people/modi/modi72.jpg
# Processing image: ./data/people/modi/modi66.jpg
# Processing image: ./data/people/modi/modi130.jpg
# Processing image: ./data/people/modi/modi118.jpg
# Processing image: ./data/people/modi/modi119.jpg
# Processing image: ./data/people/modi/modi125.jpg
# Processing image: ./data/people/modi/modi131.jpg
# Processing image: ./data/people/modi/modi67.jpg
# Processing image: ./data/people/modi/modi73.jpg
# Processing image: ./data/people/modi/modi98.jpg
# Processing image: ./data/people/modi/modi59.jpg
# Processing image: ./data/people/modi/modi65.jpg
# Processing image: ./data/people/modi/modi71.jpg
# Processing image: ./data/people/modi/modi127.jpg
# Processing image: ./data/people/modi/modi133.jpg
# Processing image: ./data/people/modi/modi132.jpg
# Processing image: ./data/people/modi/modi126.jpg
# Processing image: ./data/people/modi/modi70.jpg
# Processing image: ./data/people/modi/modi64.jpg
# Processing image: ./data/people/modi/modi58.jpg
# Processing image: ./data/people/jack/jack44.jpg
# Processing image: ./data/people/jack/jack50.jpg
# Processing image: ./data/people/jack/jack78.jpg
# Processing image: ./data/people/jack/jack87.jpg
# Processing image: ./data/people/jack/jack93.jpg
# Processing image: ./data/people/jack/jack117.jpg
# Processing image: ./data/people/jack/jack92.jpg
# Processing image: ./data/people/jack/jack86.jpg
# Processing image: ./data/people/jack/jack79.jpg
# Processing image: ./data/people/jack/jack51.jpg
# Error: No face found in ./data/people/jack/jack51.jpg
# Processing image: ./data/people/jack/jack45.jpg
# Processing image: ./data/people/jack/jack53.jpg
# Processing image: ./data/people/jack/jack47.jpg
# Processing image: ./data/people/jack/jack90.jpg
# Processing image: ./data/people/jack/jack84.jpg
# Processing image: ./data/people/jack/jack128.jpg
# Error: No face found in ./data/people/jack/jack128.jpg
# Processing image: ./data/people/jack/jack114.jpg
# Processing image: ./data/people/jack/jack100.jpg
# Processing image: ./data/people/jack/jack115.jpg
# Processing image: ./data/people/jack/jack85.jpg
# Processing image: ./data/people/jack/jack91.jpg
# Processing image: ./data/people/jack/jack46.jpg
# Processing image: ./data/people/jack/jack52.jpg
# Processing image: ./data/people/jack/jack56.jpg
# Processing image: ./data/people/jack/jack42.jpg
# Processing image: ./data/people/jack/jack95.jpg
# Processing image: ./data/people/jack/jack81.jpg
# Processing image: ./data/people/jack/jack111.jpg
# Processing image: ./data/people/jack/jack105.jpg
# Processing image: ./data/people/jack/jack139.jpg
# Processing image: ./data/people/jack/jack138.jpg
# Processing image: ./data/people/jack/jack110.jpg
# Processing image: ./data/people/jack/jack80.jpg
# Processing image: ./data/people/jack/jack94.jpg
# Processing image: ./data/people/jack/jack43.jpg
# Processing image: ./data/people/jack/jack57.jpg
# Processing image: ./data/people/jack/jack69.jpg
# Processing image: ./data/people/jack/jack41.jpg
# Error: No face found in ./data/people/jack/jack41.jpg
# Processing image: ./data/people/jack/jack55.jpg
# Processing image: ./data/people/jack/jack82.jpg
# Processing image: ./data/people/jack/jack96.jpg
# Processing image: ./data/people/jack/jack106.jpg
# Error: No face found in ./data/people/jack/jack106.jpg
# Processing image: ./data/people/jack/jack112.jpg
# Processing image: ./data/people/jack/jack107.jpg
# Processing image: ./data/people/jack/jack97.jpg
# Error: No face found in ./data/people/jack/jack97.jpg
# Processing image: ./data/people/jack/jack83.jpg
# Processing image: ./data/people/jack/jack54.jpg
# Processing image: ./data/people/jack/jack40.jpg
# Processing image: ./data/people/jack/jack68.jpg
# Processing image: ./data/people/jack/jack27.jpg
# Processing image: ./data/people/jack/jack33.jpg
# Processing image: ./data/people/jack/jack149.jpg
# Processing image: ./data/people/jack/jack32.jpg
# Processing image: ./data/people/jack/jack26.jpg
# Processing image: ./data/people/jack/jack30.jpg
# Processing image: ./data/people/jack/jack24.jpg
# Processing image: ./data/people/jack/jack18.jpg
# Processing image: ./data/people/jack/jack19.jpg
# Processing image: ./data/people/jack/jack25.jpg
# Processing image: ./data/people/jack/jack31.jpg
# Error: No face found in ./data/people/jack/jack31.jpg
# Processing image: ./data/people/jack/jack35.jpg
# Processing image: ./data/people/jack/jack21.jpg
# Processing image: ./data/people/jack/jack20.jpg
# Processing image: ./data/people/jack/jack34.jpg
# Processing image: ./data/people/jack/jack22.jpg
# Processing image: ./data/people/jack/jack36.jpg
# Processing image: ./data/people/jack/jack8.jpg
# Processing image: ./data/people/jack/jack9.jpg
# Processing image: ./data/people/jack/jack37.jpg
# Processing image: ./data/people/jack/jack23.jpg
# Processing image: ./data/people/jack/jack12.jpg
# Processing image: ./data/people/jack/jack4.jpg
# Processing image: ./data/people/jack/jack141.jpg
# Processing image: ./data/people/jack/jack5.jpg
# Processing image: ./data/people/jack/jack13.jpg
# Processing image: ./data/people/jack/jack11.jpg
# Processing image: ./data/people/jack/jack39.jpg
# Processing image: ./data/people/jack/jack7.jpg
# Error: No face found in ./data/people/jack/jack7.jpg
# Processing image: ./data/people/jack/jack142.jpg
# Processing image: ./data/people/jack/jack143.jpg
# Processing image: ./data/people/jack/jack6.jpg
# Processing image: ./data/people/jack/jack38.jpg
# Processing image: ./data/people/jack/jack10.jpg
# Processing image: ./data/people/jack/jack28.jpg
# Processing image: ./data/people/jack/jack14.jpg
# Processing image: ./data/people/jack/jack2.jpg
# Processing image: ./data/people/jack/jack147.jpg
# Processing image: ./data/people/jack/jack146.jpg
# Processing image: ./data/people/jack/jack3.jpg
# Processing image: ./data/people/jack/jack15.jpg
# Processing image: ./data/people/jack/jack29.jpg
# Processing image: ./data/people/jack/jack17.jpg
# Processing image: ./data/people/jack/jack1.jpg
# Processing image: ./data/people/jack/jack144.jpg
# Processing image: ./data/people/jack/jack145.jpg
# Processing image: ./data/people/jack/jack0.jpg
# Processing image: ./data/people/jack/jack16.jpg
# Processing image: ./data/people/jack/jack65.jpg
# Processing image: ./data/people/jack/jack71.jpg
# Processing image: ./data/people/jack/jack59.jpg
# Processing image: ./data/people/jack/jack136.jpg
# Processing image: ./data/people/jack/jack137.jpg
# Processing image: ./data/people/jack/jack123.jpg
# Processing image: ./data/people/jack/jack58.jpg
# Processing image: ./data/people/jack/jack70.jpg
# Processing image: ./data/people/jack/jack64.jpg
# Processing image: ./data/people/jack/jack72.jpg
# Processing image: ./data/people/jack/jack66.jpg
# Processing image: ./data/people/trump/donald trump speech104.jpg
# Processing image: ./data/people/trump/donald trump speech138.jpg
# Processing image: ./data/people/trump/donald trump speech139.jpg
# Processing image: ./data/people/trump/donald trump speech105.jpg
# Processing image: ./data/people/trump/trump47.jpg
# Processing image: ./data/people/trump/trump4.jpg
# Processing image: ./data/people/trump/donald trump89.jpg
# Processing image: ./data/people/trump/donald trump76.jpg
# Processing image: ./data/people/trump/donald trump62.jpg
# Processing image: ./data/people/trump/trump34.jpg
# Processing image: ./data/people/trump/trump20.jpg
# Processing image: ./data/people/trump/trump21.jpg
# Processing image: ./data/people/trump/trump35.jpg
# Processing image: ./data/people/trump/donald trump63.jpg
# Processing image: ./data/people/trump/donald trump77.jpg
# Processing image: ./data/people/trump/donald trump88.jpg
# Processing image: ./data/people/trump/trump5.jpg
# Processing image: ./data/people/trump/trump7.jpg
# Processing image: ./data/people/trump/donald trump61.jpg
# Processing image: ./data/people/trump/donald trump75.jpg
# Processing image: ./data/people/trump/trump23.jpg
# Processing image: ./data/people/trump/trump37.jpg
# Processing image: ./data/people/trump/donald trump100.jpg
# Error: No face found in ./data/people/trump/donald trump100.jpg
# Processing image: ./data/people/trump/donald trump speech149.jpg
# Processing image: ./data/people/trump/donald trump speech148.jpg
# Processing image: ./data/people/trump/trump36.jpg
# Processing image: ./data/people/trump/trump22.jpg
# Processing image: ./data/people/trump/donald trump74.jpg
# Processing image: ./data/people/trump/donald trump60.jpg
# Processing image: ./data/people/trump/trump6.jpg
# Processing image: ./data/people/trump/trump2.jpg
# Processing image: ./data/people/trump/donald trump64.jpg
# Processing image: ./data/people/trump/donald trump70.jpg
# Processing image: ./data/people/trump/donald trump58.jpg
# Processing image: ./data/people/trump/trump26.jpg
# Processing image: ./data/people/trump/trump32.jpg
# Processing image: ./data/people/trump/trump33.jpg
# Processing image: ./data/people/trump/trump27.jpg
# Processing image: ./data/people/trump/donald trump59.jpg
# Processing image: ./data/people/trump/donald trump71.jpg
# Processing image: ./data/people/trump/donald trump65.jpg
# Processing image: ./data/people/trump/trump3.jpg
# Processing image: ./data/people/trump/trump1.jpg
# Processing image: ./data/people/trump/donald trump98.jpg
# Error: No face found in ./data/people/trump/donald trump98.jpg
# Processing image: ./data/people/trump/donald trump73.jpg
# Processing image: ./data/people/trump/donald trump67.jpg
# Processing image: ./data/people/trump/trump19.jpg
# Processing image: ./data/people/trump/trump31.jpg
# Processing image: ./data/people/trump/trump25.jpg
# Processing image: ./data/people/trump/trump24.jpg
# Processing image: ./data/people/trump/trump30.jpg
# Processing image: ./data/people/trump/trump18.jpg
# Processing image: ./data/people/trump/donald trump66.jpg
# Processing image: ./data/people/trump/donald trump72.jpg
# Processing image: ./data/people/trump/donald trump99.jpg

# %%
# Initialize shared variables for inter-process communication
manager = Manager()
read_frame_list = manager.list([None] * cpu_count())  # List to store frames for reading
write_frame_list = manager.list([None] * cpu_count())  # List to store frames for writing
frame_delay = 0.01  # Delay between frames for smoother video
is_exit = False  # Flag to indicate if the program should exit
buff_num = cpu_count()  # Buffer index for reading frames
read_num = cpu_count()  # Frame index for reading frames
write_num = 1  # Frame index for writing frames

# %% [markdown]
# ### Main Recognition functions

# %%
# Set up the capture process
def capture(read_frame_list, is_exit, buff_num):
    video_capture = cv2.VideoCapture(0)
    while not is_exit.value:
        if buff_num.value != read_num.value:
            ret, frame = video_capture.read()
            read_frame_list[buff_num.value] = frame
            buff_num.value = next_id(buff_num.value, cpu_count())
        else:
            time.sleep(0.01)
    video_capture.release()

# Set up the processing processes
def process(worker_id, read_frame_list, write_frame_list, is_exit, read_num, buff_num, write_num):
    while not is_exit.value:
        while read_num.value != worker_id or read_num.value != prev_id(buff_num.value, cpu_count()):
            if is_exit.value:
                break
            time.sleep(0.01)

        time.sleep(frame_delay)
        frame_process = read_frame_list[worker_id]
        read_num.value = next_id(read_num.value, cpu_count())

        rgb_frame = frame_process[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            matches = face_recognition.compare_faces(known_faces, face_encoding)
            name = "Unknown"
            face_distances = face_recognition.face_distance(known_faces, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_labels[best_match_index]
            face_names.append(name)

        for (top, right, bottom, left), name in zip(face_locations, face_names):
            cv2.rectangle(frame_process, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2.rectangle(frame_process, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
            font = cv2.FONT_HERSHEY_DUPLEX
            cv2.putText(frame_process, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

        while write_num != worker_id:

            time.sleep(0.01)

        write_frame_list[worker_id] = frame_process
        write_num = next_id(write_num, cpu_count())

# %% [markdown]
# ##### Worker functions

# %%
def next_id(current_id, worker_num):
    if current_id == worker_num:
        return 1
    else:
        return current_id + 1

def prev_id(current_id, worker_num):
    if current_id == 1:
        return worker_num
    else:
        return current_id - 1

# %% [markdown]
# ### Main Code Loop

# %%
if __name__ == '__main__':
    try:
        set_start_method('spawn')
    except RuntimeError:
        pass

    # Start the capture process
    capture_process = Process(target=capture, args=(read_frame_list, is_exit, buff_num))
    capture_process.start()

    # Start the processing processes
    process_list = []
    for i in range(1, cpu_count() + 1):
        process_list.append(Process(target=process, args=(i, read_frame_list, write_frame_list, is_exit, read_num, buff_num, write_num)))
        process_list[-1].start()

    # Initialize the video capture
    video_capture = cv2.VideoCapture(0)

    
    while True:
        if 7 < len(write_frame_list):
            frame = write_frame_list[cpu_count() - 1]
            cv2.imshow('Video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            is_exit = True
            break

        if is_exit:
            break


    video_capture.release()

    # Wait for the processes to finish
    capture_process.join()
    for process in process_list:
        process.join()

    cv2.destroyAllWindows()
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'capture' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 22
#      18 video_capture = cv2.VideoCapture(0)
#      21 while True:
# ---> 22     if cpu_count() - 1 < len(write_frame_list):
#      23         frame = write_frame_list[cpu_count() - 1]
#      24         cv2.imshow('Video', frame)
#
# TypeError: 'NoneType' object cannot be interpreted as an integer
